# %%
from sklearn.datasets import make_classification
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
X, y = make_classification(
    n_features=6,
    n_classes=3,
    n_samples=800,
    n_informative=2,
    random_state=1,
    n_clusters_per_class=1,
)

# %%
# Plot the dataset
plt.figure(figsize=(8, 6))
for cls in range(3):
    plt.scatter(X[y == cls, 0], X[y == cls, 2], label=f"Class {cls}")
plt.xlabel("Feature 1")
plt.ylabel("Feature 3")
plt.title("Visualization of Normally Distributed Clusters")
plt.legend()
plt.show()

# %% [markdown]
# Use Bayesian Learning to predict the probability of each class.

# %%
# split the dataset
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %% [markdown]
# ## **Use library**

# %%
# Bayes Model
from sklearn.naive_bayes import GaussianNB

model = GaussianNB()

model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
# predict
y_pred = model.predict(X_test)

# evaluate
from sklearn.metrics import accuracy_score

print(accuracy_score(y_test, y_pred))
# Out:
# 0.8333333333333334

# %% [markdown]
# Homework: Create Bayesian Learning model to train on loan dataset (file `loan_data.csv`)
